# %%
import requests
import time
import random
import pandas as pd
from google.colab import drive
drive.mount('/content/gdrive')
# %cd '/content/gdrive/MyDrive/Tieu_luan'
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/Tieu_luan

# %%
# dien thoại may tinh bang
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36 Edg/123.0.0.0',
    'Accept': 'application/json, text/plain, */*',
    'Accept-Language': 'en-US,en;q=0.9,vi;q=0.8',
    'Referer': 'https://tiki.vn/dien-thoai-may-tinh-bang/c1789',
    'X-Guest-Token': 'pZeFlY2uoXB6Gk4aCiNbMrmIJ0LUh9Ot',
    'Connection': 'keep-alive',
    'TE': 'Trailers',
}

params = {
    'limit': '40',
    'include': 'advertisement',
    'aggregations': '2',
    'version': 'home-persionalized',
    'trackity_id': '84ad1f71-7536-61a8-44c3-24b6ae303ec8',
    'category': '1789',
    'page': '1',
    'urlKey': 'dien-thoai-may-tinh-bang',
}



product_id = []
for i in range(1, 16):
    params['page'] = i
    response = requests.get('https://tiki.vn/api/v2/products', headers=headers, params=params)
    if response.status_code == 200:
        print(f'{i} request success!!!')
        for record in response.json().get('data'):
            product_id.append({'id': record.get('id')})
    time.sleep(random.randrange(3, 10))


df = pd.DataFrame(product_id)
df.to_csv('data/product_id_tiki_1.csv', index=False)

df.shape[0]
# Out:
# 1 request success!!!
# 2 request success!!!
# 3 request success!!!
# 4 request success!!!
# 5 request success!!!
# 6 request success!!!
# 7 request success!!!
# 8 request success!!!
# 9 request success!!!
# 10 request success!!!
# 11 request success!!!
# 12 request success!!!
# 13 request success!!!
# 14 request success!!!
# 15 request success!!!
# 570

# %%
# thoi trang nu
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36 Edg/123.0.0.0',
    'Accept': 'application/json, text/plain, */*',
    'Accept-Language': 'en-US,en;q=0.9,vi;q=0.8',
    'Referer': 'https://tiki.vn/thoi-trang-nu/c931',
    'X-Guest-Token': 'pZeFlY2uoXB6Gk4aCiNbMrmIJ0LUh9Ot',
    'Connection': 'keep-alive',
    'TE': 'Trailers',
}

params = {
   'limit': '40',
    'include': 'advertisement',
    'aggregations': '2',
    'version': 'home-persionalized',
    'trackity_id': '84ad1f71-7536-61a8-44c3-24b6ae303ec8',
    'category': '931',
    'page': '1',
    'urlKey': 'thoi-trang-nu',

}

product_id = []
for i in range(1, 51):
    params['page'] = i
    response = requests.get('https://tiki.vn/api/v2/products', headers=headers, params=params)
    if response.status_code == 200:
        print(f'{i} request success!!!')
        for record in response.json().get('data'):
            product_id.append({'id': record.get('id')})
    time.sleep(random.randrange(3, 10))

df = pd.DataFrame(product_id)
df.to_csv('data/product_id_tiki_2.csv', index=False)

df.shape[0]
# Out:
# 1 request success!!!
# 2 request success!!!
# 3 request success!!!
# 4 request success!!!
# 5 request success!!!
# 6 request success!!!
# 7 request success!!!
# 8 request success!!!
# 9 request success!!!
# 10 request success!!!
# 11 request success!!!
# 12 request success!!!
# 13 request success!!!
# 14 request success!!!
# 15 request success!!!
# 16 request success!!!
# 17 request success!!!
# 18 request success!!!
# 19 request success!!!
# 20 request success!!!
# 21 request success!!!
# 22 request success!!!
# 23 request success!!!
# 24 request success!!!
# 25 request success!!!
# 26 request success!!!
# 27 request success!!!
# 28 request success!!!
# 29 request success!!!
# 30 request success!!!
# 31 request success!!!
# 32 request success!!!
# 33 request success!!!
# 34 request success!!!
# 35 request success!!!
# 36 request success!!!
# 37 request success!!!
# 38 request success!!!
# 39 request success!!!
# 40 request success!!!
# 41 request success!!!
# 42 request success!!!
# ...

# %%
# nha sach tiki
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36 Edg/123.0.0.0',
    'Accept': 'application/json, text/plain, */*',
    'Accept-Language': 'en-US,en;q=0.9,vi;q=0.8',
    'Referer': 'https://tiki.vn/nha-sach-tiki/c8322',
    'X-Guest-Token': 'pZeFlY2uoXB6Gk4aCiNbMrmIJ0LUh9Ot',
    'Connection': 'keep-alive',
    'TE': 'Trailers',
}

params = {
   'limit': '40',
    'include': 'advertisement',
    'aggregations': '2',
    'version': 'home-persionalized',
    'trackity_id': '84ad1f71-7536-61a8-44c3-24b6ae303ec8',
    'category': '8322',
    'page': '1',
    'urlKey': 'nha-sach-tiki',

}

product_id = []
for i in range(1, 51):
    params['page'] = i
    response = requests.get('https://tiki.vn/api/v2/products', headers=headers, params=params)
    if response.status_code == 200:
        print(f'{i} request success!!!')
        for record in response.json().get('data'):
            product_id.append({'id': record.get('id')})
    time.sleep(random.randrange(3, 10))

df = pd.DataFrame(product_id)
df.to_csv('data/product_id_tiki_3.csv', index=False)

df.shape[0]
# Out:
# 1 request success!!!
# 2 request success!!!
# 3 request success!!!
# 4 request success!!!
# 5 request success!!!
# 6 request success!!!
# 7 request success!!!
# 8 request success!!!
# 9 request success!!!
# 10 request success!!!
# 11 request success!!!
# 12 request success!!!
# 13 request success!!!
# 14 request success!!!
# 15 request success!!!
# 16 request success!!!
# 17 request success!!!
# 18 request success!!!
# 19 request success!!!
# 20 request success!!!
# 21 request success!!!
# 22 request success!!!
# 23 request success!!!
# 24 request success!!!
# 25 request success!!!
# 26 request success!!!
# 27 request success!!!
# 28 request success!!!
# 29 request success!!!
# 30 request success!!!
# 31 request success!!!
# 32 request success!!!
# 33 request success!!!
# 34 request success!!!
# 35 request success!!!
# 36 request success!!!
# 37 request success!!!
# 38 request success!!!
# 39 request success!!!
# 40 request success!!!
# 41 request success!!!
# 42 request success!!!
# ...

# %%
# bach-hoa-online/c4384
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36 Edg/123.0.0.0',
    'Accept': 'application/json, text/plain, */*',
    'Accept-Language': 'en-US,en;q=0.9,vi;q=0.8',
    'Referer': 'https://tiki.vn/bach-hoa-online/c4384',
    'X-Guest-Token': 'pZeFlY2uoXB6Gk4aCiNbMrmIJ0LUh9Ot',
    'Connection': 'keep-alive',
    'TE': 'Trailers',
}

params = {
   'limit': '40',
    'include': 'advertisement',
    'aggregations': '2',
    'version': 'home-persionalized',
    'trackity_id': '84ad1f71-7536-61a8-44c3-24b6ae303ec8',
    'category': '4384',
    'page': '1',
    'urlKey': 'bach-hoa-online',

}

product_id = []
for i in range(1, 51):
    params['page'] = i
    response = requests.get('https://tiki.vn/api/v2/products', headers=headers, params=params)
    if response.status_code == 200:
        print(f'{i} request success!!!')
        for record in response.json().get('data'):
            product_id.append({'id': record.get('id')})
    time.sleep(random.randrange(3, 10))

df = pd.DataFrame(product_id)
df.to_csv('data/product_id_tiki_4.csv', index=False)

df.shape[0]
# Out:
# 1 request success!!!
# 2 request success!!!
# 3 request success!!!
# 4 request success!!!
# 5 request success!!!
# 6 request success!!!
# 7 request success!!!
# 8 request success!!!
# 9 request success!!!
# 10 request success!!!
# 11 request success!!!
# 12 request success!!!
# 13 request success!!!
# 14 request success!!!
# 15 request success!!!
# 16 request success!!!
# 17 request success!!!
# 18 request success!!!
# 19 request success!!!
# 20 request success!!!
# 21 request success!!!
# 22 request success!!!
# 23 request success!!!
# 24 request success!!!
# 25 request success!!!
# 26 request success!!!
# 27 request success!!!
# 28 request success!!!
# 29 request success!!!
# 30 request success!!!
# 31 request success!!!
# 32 request success!!!
# 33 request success!!!
# 34 request success!!!
# 35 request success!!!
# 36 request success!!!
# 37 request success!!!
# 38 request success!!!
# 39 request success!!!
# 40 request success!!!
# 41 request success!!!
# 42 request success!!!
# ...

# %%
# nha-cua-doi-song/c1883
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36 Edg/123.0.0.0',
    'Accept': 'application/json, text/plain, */*',
    'Accept-Language': 'en-US,en;q=0.9,vi;q=0.8',
    'Referer': 'https://tiki.vn/nha-cua-doi-song/c1883',
    'X-Guest-Token': 'pZeFlY2uoXB6Gk4aCiNbMrmIJ0LUh9Ot',
    'Connection': 'keep-alive',
    'TE': 'Trailers',
}

params = {
   'limit': '40',
    'include': 'advertisement',
    'aggregations': '2',
    'version': 'home-persionalized',
    'trackity_id': '84ad1f71-7536-61a8-44c3-24b6ae303ec8',
    'category': '1883',
    'page': '1',
    'urlKey': 'nha-cua-doi-song',

}

product_id = []
for i in range(1, 51):
    params['page'] = i
    response = requests.get('https://tiki.vn/api/v2/products', headers=headers, params=params)
    if response.status_code == 200:
        print(f'{i} request success!!!')
        for record in response.json().get('data'):
            product_id.append({'id': record.get('id')})
    time.sleep(random.randrange(3, 10))

df = pd.DataFrame(product_id)
df.to_csv('data/product_id_tiki_5.csv', index=False)

df.shape[0]
# Out:
# 1 request success!!!
# 2 request success!!!
# 3 request success!!!
# 4 request success!!!
# 5 request success!!!
# 6 request success!!!
# 7 request success!!!
# 8 request success!!!
# 9 request success!!!
# 10 request success!!!
# 11 request success!!!
# 12 request success!!!
# 13 request success!!!
# 14 request success!!!
# 15 request success!!!
# 16 request success!!!
# 17 request success!!!
# 18 request success!!!
# 19 request success!!!
# 20 request success!!!
# 21 request success!!!
# 22 request success!!!
# 23 request success!!!
# 24 request success!!!
# 25 request success!!!
# 26 request success!!!
# 27 request success!!!
# 28 request success!!!
# 29 request success!!!
# 30 request success!!!
# 31 request success!!!
# 32 request success!!!
# 33 request success!!!
# 34 request success!!!
# 35 request success!!!
# 36 request success!!!
# 37 request success!!!
# 38 request success!!!
# 39 request success!!!
# 40 request success!!!
# 41 request success!!!
# 42 request success!!!
# ...

# %%
# thiet-bi-kts-phu-kien-so/c1815
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36 Edg/123.0.0.0',
    'Accept': 'application/json, text/plain, */*',
    'Accept-Language': 'en-US,en;q=0.9,vi;q=0.8',
    'Referer': 'https://tiki.vn/thiet-bi-kts-phu-kien-so/c1815',
    'X-Guest-Token': 'pZeFlY2uoXB6Gk4aCiNbMrmIJ0LUh9Ot',
    'Connection': 'keep-alive',
    'TE': 'Trailers',
}

params = {
   'limit': '40',
    'include': 'advertisement',
    'aggregations': '2',
    'version': 'home-persionalized',
    'trackity_id': '84ad1f71-7536-61a8-44c3-24b6ae303ec8',
    'category': '1815',
    'page': '1',
    'urlKey': 'thiet-bi-kts-phu-kien-so',

}

product_id = []
for i in range(1, 51):
    params['page'] = i
    response = requests.get('https://tiki.vn/api/v2/products', headers=headers, params=params)
    if response.status_code == 200:
        print(f'{i} request success!!!')
        for record in response.json().get('data'):
            product_id.append({'id': record.get('id')})
    time.sleep(random.randrange(3, 10))

df = pd.DataFrame(product_id)
df.to_csv('data/product_id_tiki_6.csv', index=False)

df.shape[0]
# Out:
# 1 request success!!!
# 2 request success!!!
# 3 request success!!!
# 4 request success!!!
# 5 request success!!!
# 6 request success!!!
# 7 request success!!!
# 8 request success!!!
# 9 request success!!!
# 10 request success!!!
# 11 request success!!!
# 12 request success!!!
# 13 request success!!!
# 14 request success!!!
# 15 request success!!!
# 16 request success!!!
# 17 request success!!!
# 18 request success!!!
# 19 request success!!!
# 20 request success!!!
# 21 request success!!!
# 22 request success!!!
# 23 request success!!!
# 24 request success!!!
# 25 request success!!!
# 26 request success!!!
# 27 request success!!!
# 28 request success!!!
# 29 request success!!!
# 30 request success!!!
# 31 request success!!!
# 32 request success!!!
# 33 request success!!!
# 34 request success!!!
# 35 request success!!!
# 36 request success!!!
# 37 request success!!!
# 38 request success!!!
# 39 request success!!!
# 40 request success!!!
# 41 request success!!!
# 42 request success!!!
# ...
